# %% [markdown]
# # 02 - Baseline Modeling\n
# Train and compare baseline models and inspect core metrics.

# %%
import json\n
from pathlib import Path\n
\n
metrics_path = Path('../artifacts/metrics.json')\n
if metrics_path.exists():\n
    print(json.loads(metrics_path.read_text(encoding='utf-8')))\n
else:\n
    print('Run python -m src.run_pipeline first.')
