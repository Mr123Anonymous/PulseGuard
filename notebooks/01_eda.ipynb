# %% [markdown]
# # 01 - Exploratory Data Analysis\n
# Use this notebook to profile cohort characteristics and readmission patterns.

# %%
import pandas as pd\n
import seaborn as sns\n
import matplotlib.pyplot as plt\n
\n
df = pd.read_csv('../data/processed/model_input.csv')\n
df.head()

# %%
target_rate = df['target_readmit_30d'].mean()\n
print(f'Target rate: {target_rate:.3f}')
