# %% [markdown]
# # 03 - Monitoring Simulation\n
# Review monthly performance and drift simulation outputs.

# %%
import pandas as pd\n
from pathlib import Path\n
\n
report_path = Path('../artifacts/monitoring_report.csv')\n
if report_path.exists():\n
    report = pd.read_csv(report_path)\n
    display(report)\n
else:\n
    print('Run python -m src.run_pipeline first.')
